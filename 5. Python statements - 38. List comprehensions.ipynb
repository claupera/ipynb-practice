# %%
# reviewing for loops

# %%
d = {"k1":1, "k2":2,"k3":3}

# %%
for item in d:
  print (item)
# Out:
# k1
# k2
# k3

# %%
for item in d.items():
  print (item)
# Out:
# ('k1', 1)
# ('k2', 2)
# ('k3', 3)

# %%
for value in d.values():
  print (value)
# Out:
# 1
# 2
# 3

# %%
for keys in d.keys():
  print (keys)
# Out:
# k1
# k2
# k3

# %%
for a,b in d.items():
  print (a)
  print (b)
# Out:
# k1
# 1
# k2
# 2
# k3
# 3

# %%
list (d.items())
# Out:
# [('k1', 1), ('k2', 2), ('k3', 3)]

# %%
list (d.values())
# Out:
# [1, 2, 3]

# %%
list (d.keys())
# Out:
# ['k1', 'k2', 'k3']

# %%
# reviewing while loops

# %%
x = 0
while x <= 10:
  x +=1
  print (f"x is currently:{x}")
  print ("x is still less than 10, adding 1 to x")
else:
  print ("all done")
# Out:
# x is currently:1
# x is still less than 10, adding 1 to x
# x is currently:2
# x is still less than 10, adding 1 to x
# x is currently:3
# x is still less than 10, adding 1 to x
# x is currently:4
# x is still less than 10, adding 1 to x
# x is currently:5
# x is still less than 10, adding 1 to x
# x is currently:6
# x is still less than 10, adding 1 to x
# x is currently:7
# x is still less than 10, adding 1 to x
# x is currently:8
# x is still less than 10, adding 1 to x
# x is currently:9
# x is still less than 10, adding 1 to x
# x is currently:10
# x is still less than 10, adding 1 to x
# x is currently:11
# x is still less than 10, adding 1 to x
# all done

# %%
# importa donde pongo el x+=1, primero printea o primero adds 1, pero no entiendo por que arriba llega hasta 11

# %%
x = 0
while x <= 10:
  print (f"x is currently:{x}")
  print ("x is still less than 10, adding 1 to x")
  x +=1
else:
  print ("all done")
# Out:
# x is currently:0
# x is still less than 10, adding 1 to x
# x is currently:1
# x is still less than 10, adding 1 to x
# x is currently:2
# x is still less than 10, adding 1 to x
# x is currently:3
# x is still less than 10, adding 1 to x
# x is currently:4
# x is still less than 10, adding 1 to x
# x is currently:5
# x is still less than 10, adding 1 to x
# x is currently:6
# x is still less than 10, adding 1 to x
# x is currently:7
# x is still less than 10, adding 1 to x
# x is currently:8
# x is still less than 10, adding 1 to x
# x is currently:9
# x is still less than 10, adding 1 to x
# x is currently:10
# x is still less than 10, adding 1 to x
# all done

# %%
x = 4
while x %2 == 0:
  print ("is an even number, we are fine")
else:
  print ("Oh, oh, now we stop")
# Out:
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# is an even number, we are fine
# ...

# %%
x = 4
while x %2 == 0:
  x +=1
  print (f"{x} is an even number, we are fine")
else:
  print ("Oh, oh, now we stop")
# Out:
# 5 is an even number, we are fine
# Oh, oh, now we stop

# %%
x = 4
while x %2 == 0:
  print (f"{x} is an even number, we are fine")
  x +=1
  if x %2 !=0 and x <= 10 :
    print (f"We continue for a bit, but {x} is an odd number")
    x +=1
    continue
else:
    print (f"Oh, oh, now we stop. We reached {x}")
# Out:
# 4 is an even number, we are fine
# We continue for a bit, but 5 is an odd number
# 6 is an even number, we are fine
# We continue for a bit, but 7 is an odd number
# 8 is an even number, we are fine
# We continue for a bit, but 9 is an odd number
# 10 is an even number, we are fine
# Oh, oh, now we stop. We reached 11

# %%
# este break de x == 8 no funciona

# %%
x = 4
while x %2 == 0:
  print (f"{x} is an even number, we are fine")
  x +=1
  if x %2 !=0 and x <= 10 :
    print (f"We continue for a bit, but {x} is an odd number")
    x +=1
    continue
  if x == 8:
    break
else:
    print (f"Oh, oh, now we stop. We reached {x}")
# Out:
# 4 is an even number, we are fine
# We continue for a bit, but 5 is an odd number
# 6 is an even number, we are fine
# We continue for a bit, but 7 is an odd number
# 8 is an even number, we are fine
# We continue for a bit, but 9 is an odd number
# 10 is an even number, we are fine
# Oh, oh, now we stop. We reached 11

# %%
mytext = "python"
for letter in mytext:
  print (letter)
# Out:
# p
# y
# t
# h
# o
# n

# %%
numbers = [1,4,6,4]
total = 0
for num in numbers:
  total += num
  print (total)
# Out:
#   File "<ipython-input-62-e393e8602dcb>", line 4
#     total+ = num
#            ^
# SyntaxError: invalid syntax
